# %% [markdown]
# Cell 1: Setup
#
# Run this once to start the system.

# %% [markdown]
# Cell 2: Configuration (The User Form)
#
# This cell creates the settings menu.

# %% [markdown]
# Cell 3: Run Analysis
#
# The main engine. It handles the "Dynamic Resolution" logic automatically.
